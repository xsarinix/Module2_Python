# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_csv="avg_rain_state.csv"
rain_data=pd.read_csv(rain_csv)
rain_data.describe()
# Out:
#           Inches  Milli­metres       Rank
# count  50.000000     50.000000  50.000000
# mean   37.078000    941.820000  25.480000
# std    14.635898    371.752095  14.599748
# min     9.500000    241.000000   1.000000
# 25%    24.525000    622.500000  13.250000
# 50%    41.750000   1061.000000  25.500000
# 75%    47.850000   1216.250000  37.750000
# max    63.700000   1618.000000  50.000000

# %%
# Set x axis and tick locations
x_axis=np.arange(len(state_name))
tick_locations=[value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_data["Inches"], color="r", alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_data["State"], rotation="vertical")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_data["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.tight_layout()
plt.savefig("avg_state_rain.png")
plt.show()

# %%
# Save our graph and show the grap

# %%
avg_rain=rain_data["Inches"]
plt.bar(x_axis, avg_rain, color="r", alpha=0.5, alight="center")
